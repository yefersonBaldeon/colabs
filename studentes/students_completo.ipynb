# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import pandas as pd
from sklearn import datasets
# %matplotlib inline

# %%
df= pd.read_csv('dataset.csv')
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.shape
# Out:
# (480, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
sns.countplot(data=df,x="Class")

# %%
sns.countplot(x='Class',hue='gender',data=df)

# %%
sns.pairplot(df,hue='Class')

# %%
df["raisedhands"].hist() # alumnos que hacen las manos

# %%
df["gender"].value_counts()
# Out:
# M    305
# F    175
# Name: gender, dtype: int64

# %%
sns.countplot(data=df,x="gender")

# %%
df['NationalITy'].value_counts()
# Out:
# KW             179
# Jordan         172
# Palestine       28
# Iraq            22
# lebanon         17
# Tunis           12
# SaudiArabia     11
# Egypt            9
# Syria            7
# USA              6
# Iran             6
# Lybia            6
# Morocco          4
# venzuela         1
# Name: NationalITy, dtype: int64

# %%
df['PlaceofBirth'].value_counts()
# Out:
# KuwaIT         180
# Jordan         176
# Iraq            22
# lebanon         19
# SaudiArabia     16
# USA             16
# Palestine       10
# Egypt            9
# Tunis            9
# Iran             6
# Syria            6
# Lybia            6
# Morocco          4
# venzuela         1
# Name: PlaceofBirth, dtype: int64

# %%
df['StageID'].value_counts()
# Out:
# MiddleSchool    248
# lowerlevel      199
# HighSchool       33
# Name: StageID, dtype: int64

# %%
df['GradeID'].value_counts()
# Out:
# G-02    147
# G-08    116
# G-07    101
# G-04     48
# G-06     32
# G-11     13
# G-12     11
# G-09      5
# G-10      4
# G-05      3
# Name: GradeID, dtype: int64

# %%
df['Semester'].value_counts()  # first second  // en que año se encuentran
# Out:
# F    245
# S    235
# Name: Semester, dtype: int64

# %%
df['Relation'].value_counts() # quien es responsable del alumno
# Out:
# Father    283
# Mum       197
# Name: Relation, dtype: int64

# %%
df['raisedhands'].value_counts()  #cuantas veces levanta la mano
# Out:
# 10    31
# 70    31
# 80    28
# 72    17
# 50    17
#       ..
# 61     1
# 83     1
# 52     1
# 67     1
# 97     1
# Name: raisedhands, Length: 82, dtype: int64

# %%
df['ParentAnsweringSurvey'].value_counts()  #los padres respondieron las encuestas
# Out:
# Yes    270
# No     210
# Name: ParentAnsweringSurvey, dtype: int64

# %%
df['ParentschoolSatisfaction'].value_counts()  #grado de satisfaccion de los padres
# Out:
# Good    292
# Bad     188
# Name: ParentschoolSatisfaction, dtype: int64

# %%
df['StudentAbsenceDays'].value_counts()  #cantidad de dias ausentes del estudiante
# Out:
# Under-7    289
# Above-7    191
# Name: StudentAbsenceDays, dtype: int64

# %% [markdown]
# **Clasificación del aprendizaje del alumno: HIGH MEDIUM LOW**

# %%
df['Class'].value_counts()
# Out:
# M    211
# H    142
# L    127
# Name: Class, dtype: int64

# %%
sns.countplot(data=df,x="Class")

# %%
sns.countplot(data=df,x="Class",hue="gender")

# %%
a=df.drop("Class",axis=1)
a
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
a= pd.get_dummies(a, drop_first=True)

# %%
a
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion  gender_M  \
# 0             15                16                  2          20         1
# 1             20                20                  3          25         1
# 2             10                 7                  0          30         1
# 3             30                25                  5          35         1
# 4             40                50                 12          50         1
# ..           ...               ...                ...         ...       ...
# 475            5                 4                  5           8         0
# 476           50                77                 14          28         0
# 477           55                74                 25          29         0
# 478           30                17                 14          57         0
# 479           35                14                 23          62         0
#
# ...

# %%
x = a.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x.shape,y.shape
# Out:
# ((480, 59), (480,))

# %%
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((384, 59), (384,), (96, 59), (96,))

# %% [markdown]
# # **Algoritmos Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB


classifier = GaussianNB()
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))

print('Confusion matrix')
sns.heatmap(confusion_matrix(y_test, y_pred),cmap='YlGn_r',annot=True,fmt='g')

# Accuracy score
from sklearn.metrics import accuracy_score
print('\naccuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            H       0.50      0.57      0.53        28
#            L       0.38      0.87      0.53        23
#            M       0.75      0.20      0.32        45
#
#     accuracy                           0.47        96
#    macro avg       0.54      0.55      0.46        96
# weighted avg       0.59      0.47      0.43        96
#
# Confusion matrix
#
# accuracy is 0.46875

# %% [markdown]
# # **SVC MAQUINA DE VECTORES DE SOPORTE**

# %%
# Support Vector Machine's 
from sklearn.svm import SVC

classifier = SVC()
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))

print('Confusion matrix')
sns.heatmap(confusion_matrix(y_test, y_pred),cmap='YlGn_r',annot=True,fmt='g')

# Accuracy score
from sklearn.metrics import accuracy_score
print('\naccuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            H       0.48      0.50      0.49        28
#            L       0.73      0.96      0.83        23
#            M       0.62      0.51      0.56        45
#
#     accuracy                           0.61        96
#    macro avg       0.61      0.66      0.63        96
# weighted avg       0.61      0.61      0.61        96
#
# Confusion matrix
#
# accuracy is 0.6145833333333334

# %% [markdown]
# # **K-Nearest Neighbours**

# %%
# K-Nearest Neighbours
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors=8)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))

print('Confusion matrix')
sns.heatmap(confusion_matrix(y_test, y_pred),cmap='YlGn_r',annot=True,fmt='g')

# Accuracy score
from sklearn.metrics import accuracy_score
print('\naccuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            H       0.53      0.57      0.55        28
#            L       0.80      0.87      0.83        23
#            M       0.63      0.58      0.60        45
#
#     accuracy                           0.65        96
#    macro avg       0.66      0.67      0.66        96
# weighted avg       0.64      0.65      0.64        96
#
# Confusion matrix
#
# accuracy is 0.6458333333333334

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=80,max_features='auto', max_depth=9,min_samples_leaf=1,
                             min_samples_split=2,bootstrap=True, random_state = 42)
rfc.fit(x_train,y_train)
rfcpred = rfc.predict(x_test)

# %%
print(classification_report(y_test, rfcpred))

print('Confusion matrix')
sns.heatmap(confusion_matrix(y_test,rfcpred),cmap='YlGn_r',annot=True,fmt='g')

# Accuracy score
from sklearn.metrics import accuracy_score
print('\naccuracy is',accuracy_score(y_pred,rfcpred))
# Out:
#               precision    recall  f1-score   support
#
#            H       0.70      0.57      0.63        28
#            L       0.87      0.87      0.87        23
#            M       0.70      0.78      0.74        45
#
#     accuracy                           0.74        96
#    macro avg       0.76      0.74      0.74        96
# weighted avg       0.74      0.74      0.74        96
#
# Confusion matrix
#
# accuracy is 0.7395833333333334
